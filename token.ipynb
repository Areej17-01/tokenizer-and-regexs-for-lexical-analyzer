# %%
#code="func test_code(): a=int(12) return a"

# %%
text=open("our_code.txt","r")

# %%
text=open("our_code.txt","r")
text_1=text.read()

# %%
text_1
# Out:
# 'int a = 7\n# a = 3\nprint(a)'

# %%
operators=["+","-","*","=","++","--","+=","-=","==","/","%"]

# %%
punctuator=[",",";",":","[","]","(",")","{","}",'"','"',"'","'"]

# %%
formats=["\n","\t"]
comments=["?*","*?","?"]

# %%
words=[]
word=""
for i in text_1:
    if i in punctuator or i in operators:
        lexen=word
        words.append(word)
        words.append(i)
        word=""
    elif i == " " or i == "\n" or i=="\t":
        words.append(word)
        word=""       
    else:
        word+=i

# %%
words
# Out:
# ['int',
#  'a',
#  '',
#  '=',
#  '',
#  '7',
#  '#',
#  'a',
#  '',
#  '=',
#  '',
#  '3',
#  'print',
#  '(',
#  'a',
#  ')']

# %% [markdown]
# ### double operator dealing

# %%
words=[]
word=""
index=[]
for j,i  in enumerate(text_1):
    if i in punctuator or i in operators:
        
        if (i+text_1[j+1]) in operators:
            
            
            if j in index:
                continue
            else:
                operate=str(i+text_1[j+1])
                words.append(word)
                word=""
                words.append(operate)
            index.append(j)
            index.append(j+1)
        elif str(text_1[j-1]+i) in operators:
            print(str(text_1[j-1]+i))
            if len(operate)==2:
                operate=""
            else:
                words.append(word)
                word=""
                words.append(i)
        else:   
            words.append(word)
            words.append(i)
            word=""
            lexen=i
    elif i == " " or i == "\n" or i=="\t":
        words.append(word)
        word=""       
    else:
        word+=(i)
words.append(i)
# Out:
# ++
# ==

# %%
#words

# %% [markdown]
# ### dealing with strings

# %%
# words=[]
# word=""
# string_status=""
# for j,i  in enumerate(text_1):
#     if i == "'" or i == '"':
#         string_status+=i
#     elif len(string_status)==1:
#         word+=(i)
#     elif len(string_status)==2:
#         words.append(word)
#         word="" 
#         string_status=""
#     elif i in punctuator or i in operators:
        
#         if (i+text_1[j+1]) in operators:
#             operate=str(i+text_1[j+1])
#             words.append(word)
#             word=""
#             words.append(operate)
#         elif str(text_1[j-1]+i) in operators:
#             print(str(text_1[j-1]+i))
#             if len(operate)==2:
#                 operate=""
#             else:
#                 words.append(word)
#                 word=""
#                 words.append(i)
#         else:   
#             words.append(word)
#             words.append(i)
#             word=""
#             lexen=i
#     elif i == " " or i == "\n" or i=="\t":
#         words.append(word)
#         word=""       
#     else:
       
#         word+=(i)
# words.append(i)

# %% [markdown]
# ### code that works

# %%
words=[]
word=""
string_status=""
index=[]
for j,i  in enumerate(text_1):
    if i == "'" or i == '"':
        #print(i)
        string_status+=i
        if len(string_status)==1:
            #print(i)
            words.append(i)
    elif len(string_status)==1:
        #print(i)
        word+=(i)
    elif len(string_status)==2:
        string_status=""
       # print(i)
        words.append(word)
        words.append(text_1[j-1])
        words.append(i)
        word="" 
        
    elif i in punctuator or i in operators:
        #print(i)
        if (i+text_1[j+1]) in operators:
            if j in index:
                continue
            else:
                operate=str(i+text_1[j+1])
                words.append(word)
                word=""
                words.append(operate)
            index.append(j)
            index.append(j+1)
        elif str(text_1[j-1]+i) in operators:
            #print(str(text_1[j-1]+i))
            if len(operate)==2:
                operate=""
            else:
                words.append(word)
                word=""
                words.append(i)
        else:   
            words.append(word)
            words.append(i)
            word=""
            lexen=i
    elif i == " " or i == "\n" or i=="\t":
        words.append(word)
        word=""       
    else:
       
        word+=(i)
words.append(i)

# %%
#words

# %% [markdown]
# ### dealing with comments

# %%
words=[]
word=""
for j,i  in enumerate(text_1):
    if i in punctuator or i in operators:
        if (i+text_1[j+1]) in operators:
            operate=str(i+text_1[j+1])
            words.append(word)
            word=""
            words.append(operate)
        elif str(text_1[j-1]+i) in operators:
            print(str(text_1[j-1]+i))
            if len(operate)==2:
                operate=""
            else:
                words.append(word)
                word=""
                words.append(i)
        else:   
            words.append(word)
            words.append(i)
            word=""
            lexen=i
    elif i == " " or i == "\n" or i=="\t":
        words.append(word)
        word=""       
    else:
       
        word+=(i)
words.append(i)
# Out:
# ++
# ==

# %%
words=[]
word=""
string_status=""
index=[]
comment_status=""
for j,i  in enumerate(text_1):
#cooments checking
    if i == "'" or i == '"':
        string_status+=i
        if len(string_status)==1:
            words.append(i)
    elif len(string_status)==1:
        word+=(i)
    elif len(string_status)==2:
        words.append(word)
        words.append(text_1[j-1])
        if i != "\n":
            words.append(i)
        word="" 
        string_status=""
#comments:double
    elif i == "?":
        comment_status+=i
    elif len(comment_status)==1:
        word+=(i)
    elif len(comment_status)==2:
        words.append(word)
        #words.append(text_1[j-1])
        word="" 
        comment_status=""

        
    elif i in punctuator or i in operators:
        if (i+text_1[j+1]) in operators:
            if j in index:
                continue
            else:
                operate=str(i+text_1[j+1])
                words.append(word)
                word=""
                words.append(operate)
            index.append(j)
            index.append(j+1)
        elif str(text_1[j-1]+i) in operators:
            print(str(text_1[j-1]+i))
            if len(operate)==2:
                operate=""
            else:
                words.append(word)
                word=""
                words.append(i)
        else:   
            words.append(word)
            words.append(i)
            word=""
            lexen=i
    elif i == " " or i == "\n" or i=="\t":
        words.append(word)
        word=""       
    else:
       
        word+=(i)
words.append(i)
# Out:
# ++
# ==
# ==
# ==
# ==
# +=

# %%
words
# Out:
# ['func',
#  'test_code',
#  '(',
#  '',
#  ')',
#  '',
#  ':',
#  '',
#  'this is multilined',
#  '',
#  'int',
#  'a',
#  '=',
#  '12',
#  '',
#  '',
#  'i',
#  '++',
#  '1',
#  '',
#  'i',
#  '+',
#  '',
#  '',
#  '=',
#  '',
#  '+',
#  '9',
#  '',
#  'i',
#  '==',
#  '',
#  '==',
#  '3',
#  '',
#  'str',
#  'y',
#  '',
#  '=',
#  '',
#  '"',
#  'fghd  fgh',
#  '"',
#  '',
#  'str',
#  'x',
#  '',
#  '=',
#  '',
#  '"',
#  '673 sgfgd',
#  '"',
#  '',
#  'empty_string',
#  '=',
#  '"',
#  '',
#  '"',
#  '',
#  'print',
#  '(',
#  '"',
#  'helllo @#$% ?worldd',
#  '"',
#  ')',
#  '',
#  '',
#  'for',
#  'i',
#  'in',
#  'range',
#  '(',
#  '5',
#  ')',
#  '',
#  ':',
#  '',
#  '',
#  '',
#  'print',
#  '(',
#  'dummy',
#  ')',
#  '',
#  '#single',
#  '"',
#  'line comment\n?this is comment \nand this ends here?\n\n\treturn a\n\n\twords=[]\n\tword=',
#  '',
#  'for',
#  'i',
#  'in',
#  'text_1',
#  ':',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'if',
#  'i',
#  'in',
#  'punctuator',
#  'or',
#  'i',
#  'in',
#  'operators',
#  ':',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'lexen',
#  '=',
#  'word',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'words.append',
#  '(',
#  'word',
#  ')',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'words.append',
#  '(',
#  'i',
#  ')',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'word',
#  '=',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'elif',
#  'i',
#  '',
#  '==',
#  '',
#  '',
#  '',
#  'or',
#  'i',
#  '',
#  '==',
#  '',
#  '\\n',
#  'or',
#  'i',
#  '==',
#  '\\t',
#  ':',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'words.append',
#  '(',
#  'word',
#  ')',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'word',
#  '=',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'else',
#  ':',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'word',
#  '+=',
#  'i']

# %% [markdown]
# ## half completed

# %%
words=[]
word=""
string_status=""
index=[]
comment_status=""
single=""
status=""
for j,i  in enumerate(text_1):
#cooments checking
    if i == "'" or i == '"':
        string_status+=i
        if len(string_status)==1:
            words.append(i)
    elif len(string_status)==1:
        word+=(i)
    elif len(string_status)==2:
        words.append(word)
        words.append(text_1[j-1])
        if i != "\n":
            words.append(i)
        word="" 
        string_status=""
#comments:double
    elif i == "?":
        comment_status+=i
        if len(comment_status)==1:
            words.append(i)
        
    elif len(comment_status)==1:
        word+=(i)
    elif len(comment_status)==2:
        words.append(word)
        words.append(text_1[j-1])
        words.append(i)
        word="" 
        comment_status=""
#comment:single
    elif  i == "#":
        single+=i
        status=i
        if len(comment_status)==1:
            words.append(i)
    elif status=="#" and i== "\n":
        words.append(word)
        words.append(i)
        single=""
        word=""
        
    elif len(single)==1:
        word+=(i)
   
        
    elif i in punctuator or i in operators:
        #print(i)
        if (i+text_1[j+1]) in operators:
            if j in index:
                continue
            else:
                operate=str(i+text_1[j+1])
                words.append(word)
                word=""
                words.append(operate)
            index.append(j)
            index.append(j+1)
        elif str(text_1[j-1]+i) in operators:
            print(str(text_1[j-1]+i))
            if len(operate)==2:
                operate=""
            else:
                words.append(word)
                word=""
                words.append(i)
        else:   
            words.append(word)
            words.append(i)
            word=""
            lexen=i
    elif i == " " or i == "\n" or i=="\t":
        words.append(word)
        word=""       
    else:
       
        word+=(i)
words.append(i)
# Out:
# ++
# ==
# ==
# ==
# ==
# +=

# %%
#issues
#string in comments 
#.variables remaining

# %%
words=[]
word=""
string_status=""
index=[]
comment_status=""
single=""
status=""
doub_status=""
for j,i  in enumerate(text_1):
#string checking
    if i == "'" or i == '"' and (status!="#" and doub_status !="?"):
        string_status+=i
        if len(string_status)==1:
            words.append(i)
    elif len(string_status)==1:
        word+=(i)
    elif len(string_status)==2:
        words.append(word)
        words.append(text_1[j-1])
        if i != "\n":
            words.append(i)
        word="" 
        string_status=""
#comments:double
    elif i == "?":
        doub_status=i
        comment_status+=i
        if len(comment_status)==1:
            words.append(i)
        
    elif len(comment_status)==1:
        word+=(i)
    elif len(comment_status)==2:
        words.append(word)
        words.append(text_1[j-1])
        words.append(i)
        word="" 
        comment_status=""
        doub_status=""
#comment:single
    elif  i == "#":
        single+=i
        status=i
        if len(comment_status)==1:
            words.append(i)
    elif status=="#" and i== "\n":
        words.append(word)
        words.append(i)
        single=""
        word=""
        status=""
        
    elif len(single)==1:
        word+=(i)
   
        
    elif i in punctuator or i in operators:
        #print(i)
        if (i+text_1[j+1]) in operators:
            if j in index:
                continue
            else:
                operate=str(i+text_1[j+1])
                words.append(word)
                word=""
                words.append(operate)
            index.append(j)
            index.append(j+1)
        elif str(text_1[j-1]+i) in operators:
            print(str(text_1[j-1]+i))
            if len(operate)==2:
                operate=""
            else:
                words.append(word)
                word=""
                words.append(i)
        else:   
            words.append(word)
            words.append(i)
            word=""
            lexen=i
    elif i == " " or i == "\n" or i=="\t":
        words.append(word)
        word=""       
    else:
       
        word+=(i)
words.append(i)
# Out:
# ++
# ==
# ==
# ==
# ==
# +=

# %%
#words

# %%
#"ssss"

# %%
# words=[]
# word=""
# string_status=""
# index=[]
# comment_status=""
# single=""
# status=""
# doub_status=""
# str_stat=0
# for j,i  in enumerate(text_1):
# #string checking
#     if i == "'" or i == '"' and (status!="#" and doub_status !="?"):
#         str_stat=1
#         string_status+=i
#         if len(string_status)==1:
#             words.append(i)
#     elif len(string_status)==1:
#         word+=(i)
#     elif len(string_status)==2:
#         words.append(word)
#         words.append(text_1[j-1])
#         if i != "\n":
#             words.append(i)
#         word="" 
#         string_status=""
#         str_stat
# #comments:double
#     elif i == "?" and str_stat!=1:
#         doub_status=i
#         comment_status+=i
#         if len(comment_status)==1:
#             words.append(i)
        
#     elif len(comment_status)==1:
#         word+=(i)
#     elif len(comment_status)==2:
#         words.append(word)
#         words.append(text_1[j-1])
#         words.append(i)
#         word="" 
#         comment_status=""
# #comment:single
#     elif  i == "#" and str_stat!=1:
#         single+=i
#         status=i
#         if len(comment_status)==1:
#             words.append(i)
#     elif status=="#" and i== "\n":
#         words.append(word)
#         words.append(i)
#         single=""
#         word=""
        
#     elif len(single)==1:
#         word+=(i)
   
        
#     elif i in punctuator or i in operators:
#         #print(i)
#         if (i+text_1[j+1]) in operators:
#             if j in index:
#                 continue
#             else:
#                 operate=str(i+text_1[j+1])
#                 words.append(word)
#                 word=""
#                 words.append(operate)
#             index.append(j)
#             index.append(j+1)
#         elif str(text_1[j-1]+i) in operators:
#             print(str(text_1[j-1]+i))
#             if len(operate)==2:
#                 operate=""
#             else:
#                 words.append(word)
#                 word=""
#                 words.append(i)
#         else:   
#             words.append(word)
#             words.append(i)
#             word=""
#             lexen=i
#     elif i == " " or i == "\n" or i=="\t":
#         words.append(word)
#         word=""       
#     else:
       
#         word+=(i)
# words.append(i)

# %% [markdown]
# ## Abhi ke liye final

# %% [markdown]
# ### decimal/point dealing

# %%
text=open("our_code.txt","r")
text_1=text.read()
text_1
# Out:
# 'print("pop\\npop");\n#popdf6?hkgg'

# %%
words=[]
word=""
string_status=""
index=[]
comment_status=""
single=""
status=""
doub_status=""
for j,i  in enumerate(text_1):
#string checking
    if i == "'" or i == '"' and (status!="#" and doub_status !="?"):
        string_status+=i
        if len(string_status)==1:
            words.append(i)
    elif len(string_status)==1:
        word+=(i)
    elif len(string_status)==2:
        words.append(word)
        words.append(text_1[j-1])
        if i != "\n":
            words.append(i)
        word="" 
        string_status=""
#comments:double
    elif i == "?":
        doub_status=i
        comment_status+=i
        if len(comment_status)==1:
            words.append(i)
        
    elif len(comment_status)==1:
        word+=(i)
    elif len(comment_status)==2:
        words.append(word)
        words.append(text_1[j-1])
        words.append(i)
        word="" 
        comment_status=""
        doub_status=""
#comment:single
    elif  i == "#":
        single+=i
        status=i
        if len(single)==1:
            words.append(i)
    elif status=="#" and i== "\n" or j == len(text_1)-1:
        print(word)
        words.append(word)
        words.append(i)
        single=""
        word=""
        status=""
        
    elif len(single)==1:
        
        word+=(i)
   
        
    elif i in punctuator or i in operators:
        #print(i)
        if (i+text_1[j+1]) in operators:
            if j in index:
                continue
            else:
                operate=str(i+text_1[j+1])
                words.append(word)
                word=""
                words.append(operate)
            index.append(j)
            index.append(j+1)
        elif str(text_1[j-1]+i) in operators:
           # print(str(text_1[j-1]+i))
            if len(operate)==2:
                operate=""
            else:
                words.append(word)
                word=""
                words.append(i)
        else:
            if "." in word:
                try:
                    a=float(word)
                    words.append(str(word))
                    word=""
                except:
                    if str(sys.exc_info()[0])== "<class 'ValueError'>":
                        arr=word.split(".")
                        if type(arr[0]) == int:
                            words.append(word)
                            word=""
                        else:
                            for ind,k in enumerate(arr):
                                words.append(k)
                                if ind != len(arr)-1:
                                    words.append(".")
                            word=""
                    words.append(i)

            else:
                words.append(word)
                words.append(i)
                word=""
                lexen=i
    elif i == " " or i == "\n" or i=="\t":
        if "." in word:
            try:
                a=float(word)
                words.append(str(word))
                word=""
            except:
                if str(sys.exc_info()[0])== "<class 'ValueError'>":
                    arr=word.split(".")
                    try:
                        a=int(word[0])
                        words.append((word))
                        word=""
                    except:
                        for ind,k in enumerate(arr):
                            words.append(k)
                            if ind != len(arr)-1:
                                words.append(".")
                        word=""
                words.append(i)
                
        else:
            words.append(word)
            words.append(i)
            word=""
            lexen=i
    else:
       
        word+=(i)
words.append(i)

# %%
words
# Out:
# ['print', '(', '"', 'pop\\npop', '"', ')', '', ';', '', '\n', '#', '?', 'g']

# %%
for i in words:
    if i != "" and i!=" ":
        print(i)
# Out:
# int
# a
# =
# 7
#
#
# #
#  a = 3
#
#
# print
# (
# a
# )

# %%
# floats=[]
# for i in [3.9,"k",9.0]:
#     try:
        
#         a=int(i)
#         floats.append(i)
#     except:
#         if str(sys.exc_info()[0])== "<class 'ValueError'>":
#             print("k")

# %%
floats
# Out:
# [3.9, 9.0]

# %%
words=[]
word=""
string_status=""
index=[]
comment_status=""
single=""
status=""
doub_status=""
for j,i  in enumerate(text_1):
#string checking
    if i == "'" or i == '"' and (status!="#" and doub_status !="?"):
        string_status+=i
        if len(string_status)==1:
            words.append(i)
    elif len(string_status)==1:
        word+=(i)
    elif len(string_status)==2:
        words.append(word)
        words.append(text_1[j-1])
        if i != "\n":
            words.append(i)
        word="" 
        string_status=""
#comments:double
    elif i == "?":
        doub_status=i
        comment_status+=i
        if len(comment_status)==1:
            words.append(i)
        
    elif len(comment_status)==1:
        word+=(i)
    elif len(comment_status)==2:
        words.append(word)
        words.append(text_1[j-1])
        words.append(i)
        word="" 
        comment_status=""
        doub_status=""
#comment:single
    elif  i == "#":
        
        single+=i
        status=i
        if len(single)==1:
            words.append(i)
    elif status=="#" and i== "\n" or j==len(text_1)-1:
        if j==len(text_1)-1:
            word+=i
            words.append(word)
            single=""
            word=""
        
        word+=i
        words.append(word)
        single=""
        word=""
        status=""
        
    elif len(single)==1:
       
        word+=(i)
        print(word)
   
        
    elif i in punctuator or i in operators:
        #print(i)
        if (i+text_1[j+1]) in operators:
            if j in index:
                continue
            else:
                operate=str(i+text_1[j+1])
                words.append(word)
                word=""
                words.append(operate)
            index.append(j)
            index.append(j+1)
        elif str(text_1[j-1]+i) in operators:
           # print(str(text_1[j-1]+i))
            if len(operate)==2:
                operate=""
            else:
                words.append(word)
                word=""
                words.append(i)
        else:
            if "." in word:
                try:
                    a=float(word)
                    words.append(str(word))
                    word=""
                except:
                    if str(sys.exc_info()[0])== "<class 'ValueError'>":
                        arr=word.split(".")
                        if type(arr[0]) == int:
                            words.append(word)
                            word=""
                        else:
                            for ind,k in enumerate(arr):
                                words.append(k)
                                if ind != len(arr)-1:
                                    words.append(".")
                            word=""
                    words.append(i)

            else:
                words.append(word)
                words.append(i)
                word=""
                lexen=i
    elif i == " " or i == "\n" or i=="\t":
        if "." in word:
            try:
                a=float(word)
                words.append(str(word))
                word=""
            except:
                if str(sys.exc_info()[0])== "<class 'ValueError'>":
                    arr=word.split(".")
                    try:
                        a=int(word[0])
                        words.append((word))
                        word=""
                    except:
                        for ind,k in enumerate(arr):
                            words.append(k)
                            if ind != len(arr)-1:
                                words.append(".")
                        word=""
                words.append(i)
                
        else:
            words.append(word)
            words.append(i)
            word=""
            lexen=i
    else:
       
        word+=(i)

words.append(i)
# Out:
# p
# po
# pop
# popd
# popdf
# popdf6

# %%
words
# Out:
# ['print', '(', '"', 'pop\\npop', '"', ')', '', ';', '', '\n', '#', '?', 'g']

# %%
text=open("our_code.txt","r")
text_1=text.read()
text_1
# Out:
# 'print("pop\\npop");\n#popdf6?hkgg\n'

# %%
import sys

# %%
text_1+=" "
words=[]
word=""
string_status=""
index=[]
comment_status=""
single=""
status=""
doub_status=""
for j,i  in enumerate(text_1):
    
#string checking

    if i == "'" or i == '"' and (status!="#" and doub_status !="?"):
        string_status+=i
        if len(string_status)==1:
            words.append(i)
    elif len(string_status)==1:
        word+=(i)
    elif len(string_status)==2:
        words.append(word)
        words.append(text_1[j-1])
        if i != "\n":
            words.append(i)
        word="" 
        string_status=""
        
#comments:double

    elif i == "?":
        doub_status=i
        comment_status+=i
        if len(comment_status)==1:
            words.append(i)
        
    elif len(comment_status)==1:
        word+=(i)
    elif len(comment_status)==2:
        words.append(word)
        words.append(text_1[j-1])
        words.append(i)
        word="" 
        comment_status=""
        doub_status=""
#comment:single
    elif  i == "#":
        word+=i
        single+=i
        status=i
    elif status=="#" and i== "\n" or j==len(text_1)-1:
        
        word+=i
        words.append(word)
        single=""
        word=""
        status=""
        
    elif len(single)>=1:
       
        word+=(i)
        #print(word)
   
        
    elif i in punctuator or i in operators:
        #print(i)
        if (i+text_1[j+1]) in operators:
            if j in index:
                continue
            else:
                operate=str(i+text_1[j+1])
                words.append(word)
                word=""
                words.append(operate)
            index.append(j)
            index.append(j+1)
        elif str(text_1[j-1]+i) in operators:
           # print(str(text_1[j-1]+i))
            if len(operate)==2:
                operate=""
            else:
                words.append(word)
                word=""
                words.append(i)
        else:
            if "." in word:
                try:
                    a=float(word)
                    words.append(str(word))
                    word=""
                except:
                    if str(sys.exc_info()[0])== "<class 'ValueError'>":
                        arr=word.split(".")
                        if type(arr[0]) == int:
                            words.append(word)
                            word=""
                        else:
                            for ind,k in enumerate(arr):
                                words.append(k)
                                if ind != len(arr)-1:
                                    words.append(".")
                            word=""
                    words.append(i)

            else:
                words.append(word)
                words.append(i)
                word=""
                lexen=i
    elif i == " " or i == "\n" or i=="\t":
        if "." in word:
            try:
                a=float(word)
                words.append(str(word))
                word=""
            except:
                if str(sys.exc_info()[0])== "<class 'ValueError'>":
                    arr=word.split(".")
                    try:
                        a=int(word[0])
                        words.append((word))
                        word=""
                    except:
                        for ind,k in enumerate(arr):
                            words.append(k)
                            if ind != len(arr)-1:
                                words.append(".")
                        word=""
                words.append(i)
                
        else:
            words.append(word)
            words.append(i)
            word=""
            lexen=i
    elif  j==len(text_1)-1:
        word+=i
        words.append(word)
    else:
       
        word+=(i)

# %%
words
# Out:
# ['print', '(', '"', 'pop\\npop', '"', ')', '', ';', '', '\n', '?']

# %% [markdown]
# ### newline

# %%
text=open("our_code.txt","r")
text_1=text.read()
text_1
# Out:
# 'print("pop\\npop");\n#popdf6?hkgg\n'

# %%
words=[]
word=""
string_status=""
index=[]
comment_status=""
single=""
status=""
doub_status=""
for j,i  in enumerate(text_1):
#string checking
    if i == "'" or i == '"' and (status!="#" and doub_status !="?"):
        string_status+=i
    if len(string_status)==2:
        print(word)
        words.append(word)
        word="" 
        string_status=""
    elif len(string_status)==1:
        if i == "'" or i == '"':
            pass
        else:
            word+=(i)

#comments:double
    elif i == "?":
        doub_status=i
        comment_status+=i
        if len(comment_status)==1:
            words.append(i)
        
    elif len(comment_status)==1:
        word+=(i)
    elif len(comment_status)==2:
        words.append(word)
        words.append(text_1[j-1])
        words.append(i)
        word="" 
        comment_status=""
        doub_status=""
#comment:single
    elif  i == "#":
        word+=i
        single+=i
        status=i
    elif status=="#" and i== "\n" or j==len(text_1)-1:
        
        word+=i
        words.append(word)
        single=""
        word=""
        status=""
        
    elif len(single)>=1:
       
        word+=(i)
        #print(word)
   
        
    elif i in punctuator or i in operators:
        #print(i)
        if (i+text_1[j+1]) in operators:
            if j in index:
                continue
            else:
                operate=str(i+text_1[j+1])
                words.append(word)
                word=""
                words.append(operate)
            index.append(j)
            index.append(j+1)
        elif str(text_1[j-1]+i) in operators:
           # print(str(text_1[j-1]+i))
            if len(operate)==2:
                operate=""
            else:
                words.append(word)
                word=""
                words.append(i)
        else:
            if "." in word:
                try:
                    a=float(word)
                    words.append(str(word))
                    word=""
                except:
                    if str(sys.exc_info()[0])== "<class 'ValueError'>":
                        arr=word.split(".")
                        if type(arr[0]) == int:
                            words.append(word)
                            word=""
                        else:
                            for ind,k in enumerate(arr):
                                words.append(k)
                                if ind != len(arr)-1:
                                    words.append(".")
                            word=""
                    words.append(i)

            else:
                
                words.append(i)
                print(word,i)
                words.append(word)
                word=""
                lexen=i
    elif i == " " or i == "\n" or i=="\t":
        if "." in word:
            try:
                a=float(word)
                words.append(str(word))
                word=""
            except:
                if str(sys.exc_info()[0])== "<class 'ValueError'>":
                    arr=word.split(".")
                    try:
                        a=int(word[0])
                        words.append((word))
                        word=""
                    except:
                        for ind,k in enumerate(arr):
                            words.append(k)
                            if ind != len(arr)-1:
                                words.append(".")
                        word=""
                words.append(i)
                
        else:
            #print(word)
            words.append(word)
            words.append(i)
            word=""
            lexen=i
    elif  j==(len(text_1)-1):
        print(word,"8")
        word+=i
        words.append(word)
    else:
       
        word+=(i)
# Out:
# print (
# pop\npop
#  )
#  ;

# %%
words
# Out:
# ['(', 'print', 'pop\\npop', ')', '', ';', '', '', '\n', '?']

# %% [markdown]
# ### working fine

# %%
text=open("our_code.txt","r")
text_1=text.read()
text_1
# Out:
# '\n#popdf6?hkgg\n?6765?'

# %%
text_1+=" "

words=[]
word=""
string_status=""
index=[]
comment_status=""
single=""
status=""
doub_status=""
for j,i  in enumerate(text_1):
#string checking
    if i == "'" or i == '"' and (status!="#" and doub_status !="?"):
        string_status+=i
    if len(string_status)==2:
        print(word)
        idk=word
        if "\\n" in word:
            newline=word.split("\\n")
            for new in newline:
                words.append(new)
            word=""
            string_status=""
        else:
            words.append(word)
            word="" 
            string_status=""
    elif len(string_status)==1:
        if i == "'" or i == '"':
            pass
        else:
            word+=(i)

#comments:double
    elif i == "?" and (status!="#"):
        doub_status=i
        comment_status+=i
        if len(comment_status)==1:
            words.append(i)
        
    elif len(comment_status)==1:
        word+=(i)
    elif len(comment_status)==2:
        words.append(word)
        words.append(text_1[j-1])
        words.append(i)
        word="" 
        comment_status=""
        doub_status=""
#comment:single
    elif  i == "#":
        print(word)
        word+=i
        single+=i
        status=i
    elif status=="#" and i== "\n" or (j==len(text_1)-2):
        
        print(word)
        word+=i
        words.append(word)
        single=""
        word=""
        status=""
        
    elif len(single)>=1:
       
        word+=(i)
        #print(word)
   
        
    elif i in punctuator or i in operators:
        #print(i)
        if (i+text_1[j+1]) in operators:
            if j in index:
                pass
            else:
                operate=str(i+text_1[j+1])
                words.append(word)
                word=""
                words.append(operate)
            index.append(j)
            index.append(j+1)
        elif str(text_1[j-1]+i) in operators:
           # print(str(text_1[j-1]+i))
            if len(operate)==2:
                operate=""
            else:
                words.append(word)
                word=""
                words.append(i)
        else:
            if "." in word:
                try:
                    a=float(word)
                    words.append(str(word))
                    word=""
                except:
                    if str(sys.exc_info()[0])== "<class 'ValueError'>":
                        arr=word.split(".")
                        if type(arr[0]) == int:
                            words.append(word)
                            word=""
                        else:
                            for ind,k in enumerate(arr):
                                words.append(k)
                                if ind != len(arr)-1:
                                    words.append(".")
                            word=""
                    words.append(i)

            else:
                words.append(word)
                words.append(i)
                word=""
                lexen=i
    elif i == " " or i == "\n" or i=="\t":
        if "." in word:
            try:
                a=float(word)
                words.append(str(word))
                word=""
            except:
                if str(sys.exc_info()[0])== "<class 'ValueError'>":
                    arr=word.split(".")
                    try:
                        a=int(word[0])
                        words.append((word))
                        word=""
                    except:
                        for ind,k in enumerate(arr):
                            words.append(k)
                            if ind != len(arr)-1:
                                words.append(".")
                        word=""
                words.append(i)
                
        else:
            words.append(word)
            words.append(i)
            word=""
            lexen=i
    elif  j==len(text_1)-1:
        print("here")
        word+=i
        words.append(word)
    else:
       
        word+=(i)
# Out:
# #popdf6?hkgg

# %%
words
# Out:
# ['', '\n', '#popdf6?hkgg\n', '?', '6765', '?', ' ']

# %% [markdown]
# ### checking comments

# %%
text=open("our_code.txt","r")
text_1=text.read()
text_1
# Out:
# 'int a = 7;\nfunc test_code():\n?this is"" multilined?\n\tint a=12 \n\ti++1\n\ta.7\n\t7.a\n\ti+ =+9\n\ti====3.9\t\t\n\tidk.append(9)\n\tstr y = "fghd  fgh"\n\tstr x = "673 sgfgd"\n\tempty_string=""\n\tprint("helllo @#$% ?worldd")\n\tfor i in range(5):\n\t\tprint(dummy)\n#single "line comment\n?this is comment \nand this ends here?\n\n\treturn a\n\n\twords=[]\n\tword=""\n\tfor i in text_1:\n    \t\tif i in punctuator or i in operators:\n        \t\tlexen=word\n        \t\twords.append(word)\n       \t\t\twords.append(i)\n        \t\tword=""\n   \t\telif i == " " or i == "\\n" or i=="\\t":\n       \t\t \twords.append(word)\n        \t\tword=""       \n    \t\telse:\n        \t\tword+=i'

# %%
text_1+=" "
words=[]
word=""
string_status=""
index=[]
comment_status=""
single=""
status=""
doub_status=""
for j,i  in enumerate(text_1):
#string checking
    if i == "'" or i == '"' and (status!="#" and doub_status !="?"):
        string_status+=i
    if len(string_status)==2:
        #print(word)
        idk=word
        if "\\n" in word:
            newline=word.split("\\n")
            for new in newline:
                words.append(new)
            word=""
            string_status=""
        else:
            words.append(word)
            word="" 
            string_status=""
    elif len(string_status)==1:
        if i == "'" or i == '"':
            pass
        else:
            word+=(i)

#comments:double
    elif i == "?" and (status!="#"):
        doub_status=i
        comment_status+=i
        if len(comment_status)==1:
            word+=i
        
    elif len(comment_status)==1:
        word+=(i)
    elif len(comment_status)==2:
        word+=(text_1[j-1])
        #words.append(word)
        
        words.append(i)
        word="" 
        comment_status=""
        doub_status=""
#comment:single
    elif  i == "#":
        #print(word)
        word+=i
        single+=i
        status=i
    elif status=="#" and i== "\n" or (j==len(text_1)-2):
        
        #print(word)
        word+=i
        #words.append(word)
        single=""
        word=""
        status=""
        
    elif len(single)>=1:
       
        word+=(i)
        #print(word)
   
        
    elif i in punctuator or i in operators:
        #print(i)
        if (i+text_1[j+1]) in operators:
            if j in index:
                pass
            else:
                operate=str(i+text_1[j+1])
                words.append(word)
                word=""
                words.append(operate)
            index.append(j)
            index.append(j+1)
        elif str(text_1[j-1]+i) in operators:
           # print(str(text_1[j-1]+i))
            if len(operate)==2:
                operate=""
            else:
                words.append(word)
                word=""
                words.append(i)
        else:
            if "." in word:
                try:
                    a=float(word)
                    words.append(str(word))
                    word=""
                except:
                    if str(sys.exc_info()[0])== "<class 'ValueError'>":
                        arr=word.split(".")
                        if type(arr[0]) == int:
                            words.append(word)
                            word=""
                        else:
                            for ind,k in enumerate(arr):
                                words.append(k)
                                if ind != len(arr)-1:
                                    words.append(".")
                            word=""
                    words.append(i)

            else:
                words.append(word)
                words.append(i)
                word=""
                lexen=i
    elif i == " " or i == "\n" or i=="\t":
        if "." in word:
            try:
                a=float(word)
                words.append(str(word))
                word=""
            except:
                if str(sys.exc_info()[0])== "<class 'ValueError'>":
                    arr=word.split(".")
                    try:
                        a=int(word[0])
                        words.append((word))
                        word=""
                    except:
                        for ind,k in enumerate(arr):
                            words.append(k)
                            if ind != len(arr)-1:
                                words.append(".")
                        word=""
                words.append(i)
                
        else:
            words.append(word)
            words.append(i)
            word=""
            lexen=i
    elif  j==len(text_1)-1:
        print("here")
        word+=i
        words.append(word)
    else:
       
        word+=(i)

# %%
for i in words:
    if i !="" and i !="\n" and i !=" ":
        print(i)
# Out:
# int
# a
# =
# 7
# ;
# func
# test_code
# (
# )
# :
#
# int
# a
# =
# 12
#
# i
# ++
# 1
#
# a
# .
# 7
#
# 7.a
#
# i
# +
# =
# +
# 9
#
# i
# ==
# 3.9
#
#
# idk
# .
# append
# (
# 9
# )
#
# str
# y
# =
# fghd  fgh
#
# str
# x
# =
# 673 sgfgd
#
# empty_string
# =
#
# print
# (
# helllo @#$% ?worldd
# )
#
# for
# i
# in
# range
# (
# 5
# )
# :
#
#
# print
# (
# dummy
# )
#
# return
# a
#
# words
# =
# [
# ]
#
# word
# =
#
# for
# i
# in
# text_1
# :
#
#
# if
# i
# in
# punctuator
# or
# i
# in
# operators
# :
#
#
# lexen
# =
# word
#
#
# words
# .
# append
# (
# word
# )
#
#
#
# words
# .
# append
# (
# i
# )
#
#
# word
# =
#
#
# elif
# i
# ==
# or
# i
# ==
# or
# i
# ==
# \t
# :
#
#
#
# words
# .
# append
# (
# word
# )
#
#
# word
# =
#
#
# else
# :
#
#
# word
# +=
# i
